# %%
# !jupyter nbconvert --to notebook --execute --inplace download.ipynb
# Out:
# [NbConvertApp] Converting notebook download.ipynb to notebook
# C:\Users\Frank\anaconda3\envs\My_First_Pandas_Project\lib\site-packages\zmq\_future.py:724: RuntimeWarning: Proactor event loop does not implement add_reader family of methods required for zmq. Registering an additional selector thread for add_reader support via tornado. Use `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())` to avoid this warning.
#   self._get_loop()
# [NbConvertApp] Writing 28868 bytes to download.ipynb
